# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "C:\\datasets\\spe\\crude-oil-price.csv"
df = pd.read_csv(path)
# get month and year from date column
df['date'] = pd.to_datetime(df['date'])
df.plot(x='date', y='price', figsize=(10, 5), title='Crude Oil Price', xlabel='Date', ylabel='Price')
# Out:
# <Axes: title={'center': 'Crude Oil Price'}, xlabel='Date', ylabel='Price'>
