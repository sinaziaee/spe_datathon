# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
path = "C:\\datasets\\spe\\World Bank Carbon Pricing.xlsx"
df = pd.read_excel(path, sheet_name='Compliance_Price', skiprows=1)

# %%
first_cols_df = df[['Name of the initiative', 'Instrument Type', 'Jurisdiction Covered', 'Region', 'Income group']]
price_cols_df = df.iloc[:, 35:]
temp_df = pd.concat([first_cols_df, price_cols_df], axis=1)
temp_df.to_csv("temp_price.csv", index=False)
temp_df
# Out:
#     Name of the initiative Instrument Type Jurisdiction Covered  \
# 0       Albania Carbon tax      Carbon tax              Albania
# 1       Alberta carbon tax      Carbon tax              Alberta
# 2             Alberta TIER             ETS              Alberta
# 3     Argentina carbon tax      Carbon tax            Argentina
# 4     Argentina carbon tax      Carbon tax            Argentina
# ..                     ...             ...                  ...
# 137     Ukraine carbon tax      Carbon tax              Ukraine
# 138        Uruguay CO2 tax      Carbon tax              Uruguay
# 139         Washington CCA             ETS           Washington
# 140     Yucatan carbon tax      Carbon tax              Yucatan
# 141   Zacatecas carbon tax      Carbon tax            Zacatecas
#
#                         Region         Income group       2017       2018  \
# 0        Europe & Central Asia  Upper middle income        NaN        NaN
# ...

# %%
import pandas as pd

new_path = "carbon_tax_price.csv"
new_df = pd.read_csv(new_path)
# new_df.drop(columns=['Unnamed: 0'], inplace=True)
new_df.to_excel("carbon_tax_price.xlsx", index=False)
